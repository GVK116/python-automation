# %%
import pandas as pd

# %%
a = pd.read_html('https://en.wikipedia.org/wiki/Lists_of_One_Piece_episodes')

# %%
a[0]
# Out:
#    Season               No.  \
#    Season Season.1      No.
# 0     NaN        1     1–61
# 1     NaN        2    62–77
# 2     NaN        3    78–91
# 3     NaN        4   92–130
# 4     NaN        5  131–143
# 5     NaN        6  144–195
# 6     NaN        7  196–228
# 7     NaN        8  229–263
# 8     NaN        9  264–336
# 9     NaN       10  337–381
# 10    NaN       11  382–407
# 11    NaN       12  408–421
# 12    NaN       13  422–456
# 13    NaN       14  457–516
# 14    NaN       15  517–578
# 15    NaN       16  579–628
# 16    NaN       17  629–746
# 17    NaN       18  747–782
# 18    NaN       19  783–891
# 19    NaN       20     892–
# 20  Total    Total    Total
#
#                                           Season name  \
#                                           Season name
# 0                                        East Blue[1]
# 1                        Entering into the Grand Line
# 2            Introducing Chopper at the Winter Island
# ...
